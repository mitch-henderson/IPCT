# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

import scipy.stats as stats
import scipy.stats.kde

# %%
#create basic histogram of region, level of concern with economy, achieving business goals over next 3 months

# %%
IPCT_data = pd.read_excel("Industry_Perspective_on_the_Challenges_of_Today_Total_Respondents.xlsx")   #read in the data. built in function from pandas

# %%
IPCT_data.shape
# Out:
# (2114, 21)

# %%
IPCT_data.columns
# Out:
# Index(['Industry Perspective on the Challenges of Today - Total Respondents',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
